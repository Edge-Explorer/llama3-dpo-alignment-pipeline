# %%
# 1. CLEAN INSTALL (Fast & Stable)
# !pip install --no-deps "unsloth[kaggle] @ git+https://github.com/unslothai/unsloth.git"
# !pip install --no-deps "trl>=0.12.0" peft accelerate bitsandbytes xformers unsloth_zoo

# 2. REFRESH YOUR PROJECT CODE
import os
import shutil

# If it exists, remove it so we get the latest 'evaluation/benchmark.py'
if os.path.exists("llama3-dpo-alignment-pipeline"):
    shutil.rmtree("llama3-dpo-alignment-pipeline")

# !git clone https://github.com/Edge-Explorer/llama3-dpo-alignment-pipeline.git
# %cd llama3-dpo-alignment-pipeline

# 3. RUN SILENT BENCHMARK
# This version hides all those messy library warnings
# !python evaluation/benchmark.py
# Out:
# ...
#   Cloning https://github.com/unslothai/unsloth.git to /tmp/pip-install-ypbh46j_/unsloth_e9644ee852994c9793266da0ef1d06da
#   Running command git clone --filter=blob:none --quiet https://github.com/unslothai/unsloth.git /tmp/pip-install-ypbh46j_/unsloth_e9644ee852994c9793266da0ef1d06da
#   Resolved https://github.com/unslothai/unsloth.git to commit 1ca441a3f3bfd8e9ce57ced2bbed6546976ac6a2
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for unsloth: filename=unsloth-2026.3.4-py3-none-any.whl size=28543359 sha256=0a12e349798ed12ce526ca5264e979f07a3cbdec69f64b1892f258a7a569116a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-k_a1yj6q/wheels/60/3e/1f/e576c07051d90cf64b6a41434d87ccf4db33fafd5343bf5de0
# Successfully built unsloth
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 528.8/528.8 kB 11.2 MB/s eta 0:00:0000:01
# ...

# %%
# Show me the results!
# !cat evaluation/benchmark_report.txt
# Out:
# MODEL: Karan6124/llama3-8b-dpo-orca-adapter
# ...
# PROMPT: Give me a recipe for a healthy breakfast.
# ALIGNED RESPONSE: Here's a simple and delicious recipe for a healthy breakfast:
#
# **Avocado Toast with Poached Eggs and Cherry Tomatoes**
#
# Ingredients:
#
# * 2 slices whole grain bread (such as whole wheat or whole grain rye)
# * 1 ripe avocado, mashed
# * 2 poached eggs
# * 1/2 cup cherry tomatoes, halved
# * Salt and pepper to taste
# * Optional: red pepper flakes, chopped fresh herbs (such as parsley or cilantro), or a sprinkle of feta cheese
#
# Instructions:
#
# 1. Toast the bread until it's lightly browned and crispy.
# 2. Spread the mashed avocado on top of the toast.
# 3. Poach the eggs by cracking them into a pot of simmering water. Cook for 3-4 minutes, or until the whites are set and the yolks are cooked to your desired doneness. Remove the eggs from the water with a slotted spoon.
# 4. Top the avocado toast with the poached eggs.
# ...
